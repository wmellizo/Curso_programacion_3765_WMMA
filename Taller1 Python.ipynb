# %%
print("Hola Mundo")
# Out:
# Hola Mundo

# %%
# Registrar los datos del trabajador por parte del usuario
No_identificacion = int(input("Digite el número de documento de identidad: "))
Nombre = input("Digite el Nombre: ")
Apellidos = input("Digite los Apellidos: ")
Direccion = input("Ingrese la Dirección: ")
Telefono = int(input("Registre el número de celular: "))
Edad = int(input("Cual es su edad: "))
Estado = input("Estado civil: ")
No_hijos = int(input("Número de hijos: "))
Estatura = int(input("Registre la estatura en centímetros: "))
dia_contrato = int(input("Registre el día de inicio del contrato: "))
mes_contrato = input("Registre el mes de inicio de contrato, ejemplo Noviembre: ")
ano_contrato = int(input("Registre el año de inicio de contrato, ejemplo 2001: "))
sueldo = float(input("Cual es el sueldo del trabajador: "))
dias_trabajados = int(input("Cantidad de días laborados entre 0 y 30: "))
# Mostrar en pantalla los datos capturados
print("Número de documento de identidad: ", No_identificacion)
print("Nombres: " + Nombre)
print("Apellidos: " + Apellidos)
print("Dirección: " + Direccion)
print("Número de Celular: ", Telefono)
print("Edad: ",Edad)
print("Estado Civil: " + Estado)
print("Cantidad de hijos: ", No_hijos)
print("Estura en centímetros: ", Estatura)
print("Fecha de Inicio del Contrato: día", dia_contrato, "Mes " + mes_contrato, "Año", ano_contrato)
print("Sueldo Básico: ", sueldo)
print("Total de días laborados: ", dias_trabajados)
# Out:
# Digite el número de documento de identidad: 79
# Digite el Nombre: W
# Digite los Apellidos: M
# Ingrese la DirecciónCALLE
# Registre el número de celular: 300
# Cual es su edad: 43
# Estado civil: S
# Número de hijos: 0
# Registre la estatura en centímetros: 162
# Registre el día de inicio del contrato: 4
# Registre el mes de inicio de contrato, ejemplo Noviembre: M
# Registre el año de inicio de contrato, ejemplo 2001: 2004
# Cual es el sueldo del trabajador: 2000
# Cantidad de días laborados entre 0 y 30: 30
# Número de documento de identidad:  79
# Nombres: W
# Apellidos: M
# Dirección: CALLE
# Número de Celular:  300
# Edad:  43
# Estado Civil: S
# Cantidad de hijos:  0
# Estura en centímetros:  162
# Fecha de Inicio del Contrato: día 4 Mes M Año 2004
# Sueldo Básico:  2000.0
# Total de días laborados:  30

# %% [markdown]
# Taller 1
#
# No de Identificación, Nombres, Apellidos, Dirección, Teléfono, Edad, Estado Civil, Número de hijos, Estatura en centímetros, fecha de contratación (Día/mes/año), Sueldo básico, Días Laborados.
